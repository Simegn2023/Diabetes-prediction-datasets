# %%
#import libraries
import pandas as pd
import numpy as np

# %%
# read the csv

url ="https://raw.githubusercontent.com/Simegn2023/Diabetes-prediction-datasets/main/Diabetes.csv"
df = pd.read_csv(url)

# %%
print(df)
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# ...

# %% [markdown]
# # Data exploration

# %%
col=df.columns
print(col)
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# print the shape of the DataFrame, so we can see how many examples we have
print( 'Shape of DataFrame: {}'.format(df.shape))
# Out:
# Shape of DataFrame: (2000, 9)

# %%
dt=df.dtypes
print(dt)
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
print(df.head(1))
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1

# %%
print(df.head(2))
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0

# %%
print(df.tail())
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 1995                     0.370   33        0
# 1996                     0.719   36        1
# 1997                     0.382   42        0
# 1998                     0.319   26        1
# 1999                     0.547   25        0

# %%
print(df.head(10))
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
# 5            0      173             78             32      265  46.5
# 6            4       99             72             17        0  25.6
# 7            8      194             80              0        0  26.1
# 8            2       83             65             28       66  36.8
# 9            2       89             90             30        0  33.5
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# ...

# %%
print(df.describe())
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  2000.000000  2000.000000    2000.000000    2000.000000  2000.000000
# mean      3.703500   121.182500      69.145500      20.935000    80.254000
# std       3.306063    32.068636      19.188315      16.103243   111.180534
# min       0.000000     0.000000       0.000000       0.000000     0.000000
# 25%       1.000000    99.000000      63.500000       0.000000     0.000000
# 50%       3.000000   117.000000      72.000000      23.000000    40.000000
# 75%       6.000000   141.000000      80.000000      32.000000   130.000000
# max      17.000000   199.000000     122.000000     110.000000   744.000000
#
#                BMI  DiabetesPedigreeFunction          Age      Outcome
# count  2000.000000               2000.000000  2000.000000  2000.000000
# mean     32.193000                  0.470930    33.090500     0.342000
# std       8.149901                  0.323553    11.786423     0.474498
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               2000 non-null   int64
#  1   Glucose                   2000 non-null   int64
#  2   BloodPressure             2000 non-null   int64
#  3   SkinThickness             2000 non-null   int64
#  4   Insulin                   2000 non-null   int64
#  5   BMI                       2000 non-null   float64
#  6   DiabetesPedigreeFunction  2000 non-null   float64
#  7   Age                       2000 non-null   int64
#  8   Outcome                   2000 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 140.8 KB
# None

# %% [markdown]
# # Data cleaning

# %%
   print(df.isnull().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
print(df.dropna())
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# ...

# %%
   dro=df.drop_duplicates()
print(dro)
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1564            1      100             62              0        0  64.4
# 1565            0      163             40             23       64  40.7
# 1566            6      139             84             37        0  50.7
# 1567            2      167             44             30      140  52.7
# 1568            3      162              0            110      215  48.7
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# ...

# %% [markdown]
# # Feature encoding

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
# One-hot encoding

# %%
   encoder = OneHotEncoder()
   one_hot_encoded_data = encoder.fit_transform(df['Age'].values.reshape(-1,1))

# %%
   encoder = OneHotEncoder()
   one_hot_encoded_data = encoder.fit_transform(df['Glucose'].values.reshape(-1,1))

# %%
df.astype({'Age':'float64'})
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction   Age  Outcome
# 0                        0.127  47.0        1
# ...

# %% [markdown]
# # Data transformation

# %%
df['normalized_column'] = (df['Age'] - df['Glucose'].min()) / (df['Age'].max() - df['Glucose'].min())

# %%
print(df)
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome  normalized_column
# ...

# %%
df.groupby('Age').agg({'Glucose': 'mean'})
# Out:
#         Glucose
# Age
# 21   110.367470
# 22   109.750000
# 23   110.019417
# 24   118.016393
# 25   110.917910
# 26   118.773810
# 27   115.382716
# 28   119.204082
# 29   128.742857
# 30   124.107143
# 31   132.500000
# 32   112.677419
# 33   124.186047
# 34   127.000000
# 35   123.111111
# 36   134.282609
# 37   128.187500
# 38   120.977778
# 39   131.333333
# 40   132.800000
# 41   125.274510
# 42   108.937500
# 43   132.617647
# 44   127.450000
# 45   132.261905
# 46   106.514286
# 47   135.294118
# 48   107.714286
# 49   150.785714
# 50   139.190476
# 51   145.692308
# 52   132.421053
# 53   144.700000
# 54   145.500000
# 55   150.928571
# 56    97.714286
# 57   129.285714
# 58   138.000000
# 59   165.500000
# 60   159.571429
# 61   144.400000
# 62   135.600000
# 63   133.923077
# 64   120.000000
# 65   134.000000
# 66   162.000000
# 67   152.200000
# 68    91.000000
# 69   134.000000
# 70   145.000000
# 72   119.000000
# 81   134.000000

# %% [markdown]
# # Data visualization

# %%
   import matplotlib.pyplot as plt
   import seaborn as sns

# %%
   plt.scatter(df['Glucose'], df['Outcome'])

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #Feature selection

# %%
from sklearn.feature_selection import SelectKBest, chi2

# %%
 X = df.drop('Outcome', axis=1)
y = df['Outcome']
selector = SelectKBest(score_func=chi2, k=5)
selector.fit(X, y)
X_new = selector.transform(X)

# %%
selected_columns = ['Pregnancies', 'Age','Glucose','Insulin','BMI']
df = df[selected_columns]

# %%
print(df)
# Out:
#       Pregnancies  Age  Glucose  Insulin   BMI
# 0               2   47      138        0  33.6
# 1               0   23       84      125  38.2
# 2               0   31      145        0  44.2
# 3               0   24      135      250  42.3
# 4               1   21      139      480  40.7
# ...           ...  ...      ...      ...   ...
# 1995            2   33       75       55  29.7
# 1996            8   36      179      130  32.7
# 1997            6   42       85        0  31.2
# 1998            0   26      129      130  67.1
# 1999            2   25       81       76  30.1
#
# [2000 rows x 5 columns]

# %% [markdown]
# # Splitting the dataset

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
  X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)

# %%
   model = LogisticRegression()
   model.fit(X_train, y_train)
   y_pred = model.predict(X_test)
   accuracy = accuracy_score(y_test, y_pred)

# %% [markdown]
# #Model evaluation
# Indented block

# %%
   from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# %%
   print(classification_report(y_test, y_pred))
   print(confusion_matrix(y_test, y_pred))
   print(roc_auc_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.83       253
#            1       0.76      0.55      0.64       147
#
#     accuracy                           0.77       400
#    macro avg       0.77      0.73      0.74       400
# weighted avg       0.77      0.77      0.76       400
#
# [[228  25]
#  [ 66  81]]
# 0.7261030894571268
